# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

plt1 = plt.figure(1)




plt.scatter(1,3, marker="o", c="red")
plt.scatter(2,2, marker="x", c="blue")
plt.scatter(2,1, marker="o", c="red")
plt.scatter(3,1, marker="o", c="red")
plt.scatter(5,4, marker="x", c="blue")
plt.title("Attribute class plot")   
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")

plt1.show()

x = np.arange(0, 1, 0.2)
plt.plot(x, 1 - x, c="red")
plt1.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
from math import exp
 

alpha=1
dataset = np.matrix([[1,3,0],
	[2,2,1],
	[2,1,0],
	[3,1,0],
	[5,4,1]])

# Make a prediction with coefficients
def predict(dataset):
    sum=0 
    coef = np.array([0,0,0])
    for data in dataset:
        sum += (1/(1 + exp(-(coef[0] + coef[1]*data.item(0) + coef[2]*data.item(1))))) - data.item(2)
    print(sum)
    coef[0] -= alpha*sum
    sum=np.array([0.,0.])
    for data in dataset:
        sum += np.array([data.item(0),data.item(1)]).dot((1/(1 + exp(-(coef[0] + coef[1]*data.item(0) + coef[2]*data.item(1)))) - data[2])))
    sum=-1*sum
    coef[1] -= alpha*sum[0]
    coef[2] -= alpha*sum[1]
    return coef
    
print(predict(dataset))
# Out:
# 0.5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-e7668c6dfada> in <module>()
#      25     return coef
#      26
# ---> 27 print(predict(dataset))
#
# <ipython-input-56-e7668c6dfada> in predict(dataset)
#      19     sum=np.array([0.,0.])
#      20     for data in dataset:
# ---> 21         sum += np.array([0,0])*(((1/(1 + exp(-(coef[0] + coef[1]*data[0] + coef[2]*data[1])))) - data[2]))
#      22     sum=-1*sum
#      23     coef[1] -= alpha*sum[0]
#
# c:\program files (x86)\python36-32\lib\site-packages\numpy\matrixlib\defmatrix.py in __getitem__(self, index)
#     282
#     283         try:
# --> 284             out = N.ndarray.__getitem__(self, index)
#     285         finally:
#     286             self._getitem = False
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
x = np.arange(0, 5, 0.02)
plt.plot(x, -x+1, c="red")
plt1.show()
