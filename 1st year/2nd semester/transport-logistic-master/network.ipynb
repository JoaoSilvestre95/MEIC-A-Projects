# %%
# %matplotlib notebook
import numpy as np
import networkx as nx
import matplotlib

network = nx.Graph()
network.add_edge('Barcelona','Gerona', weight = 2)
network.add_edge('Barcelona','Tarragona', weight = 2)
network.add_edge('Barcelona','Lerida', weight = 2)
network.add_edge('Lerida','Zaragoza', weight = 3)
network.add_edge('Zaragoza','Pamplona', weight = 4)
network.add_edge('Zaragoza','Logrono', weight = 4)
network.add_edge('Pamplona','Vitoria', weight = 2)
network.add_edge('Logrono','Vitoria', weight = 2)
network.add_edge('Pamplona','SanSebastian', weight = 2)
network.add_edge('Vitoria', 'Bilbao', weight = 2)
network.add_edge('Vitoria','Bilbao', weight = 2)
network.add_edge('SanSebastian','Bilbao', weight = 2)
network.add_edge('Vitoria','Burgos', weight = 3)
network.add_edge('Logrono','Burgos', weight = 3)
network.add_edge('Santander','Burgos', weight = 3)
network.add_edge('Santander','Bilbao', weight = 2)
network.add_edge('Santander','Oviedo', weight = 4)
network.add_edge('Gijon','Oviedo', weight = 1)
network.add_edge('Gijon','Castropol', weight = 2)
network.add_edge('Leon','Oviedo', weight = 3)
network.add_edge('Lugo','Castropol', weight = 2)
network.add_edge('Lugo','Leon', weight = 3)
network.add_edge('Lugo','LaCoruna', weight = 2)
network.add_edge('Santiago','LaCoruna', weight = 2)
network.add_edge('Santiago','Pontevedra', weight = 2)
network.add_edge('Vigo','Pontevedra', weight = 1)
network.add_edge('Vigo','Orense', weight = 1)
network.add_edge('Leon','Orense', weight = 4)
network.add_edge('Leon','Valladolid', weight = 3)
network.add_edge('Burgos','Valladolid', weight = 3)
network.add_edge('Burgos','ArandaDeDuero', weight = 2)
network.add_edge('Valladolid','ArandaDeDuero', weight = 2)
network.add_edge('Catalayud','ArandaDeDuero', weight = 4)
network.add_edge('Catalayud','Zaragoza', weight = 2)
network.add_edge('Catalayud','Teruel', weight = 4)
network.add_edge('Valencia','Teruel', weight = 4)
network.add_edge('Valencia','Terragona', weight = 5)
network.add_edge('Valencia','Tarrancon', weight = 5)
network.add_edge('Catalayud','Gadalajara', weight = 4)
network.add_edge('Madrid','Tarrancon', weight = 3)
network.add_edge('Madrid','Gadalajara', weight = 3)
network.add_edge('Madrid','ArandaDeDuero', weight = 4)
network.add_edge('Madrid','Avila', weight = 2)
network.add_edge('Madrid','Toledo', weight = 2)
network.add_edge('Madrid','Merida', weight = 6)
network.add_edge('Avila','Zamora', weight = 4)
network.add_edge('Leon','Zamora', weight = 3)
network.add_edge('Orense','Zamora', weight = 4)
network.add_edge('Salamanca','Zamora', weight = 2)
network.add_edge('Merida','Caceres', weight = 2)
network.add_edge('Merida','Badajoz', weight = 1)
network.add_edge('Madrid','Albacete', weight = 6)
network.add_edge('Valencia','Albacete', weight = 4)
network.add_edge('Albacete','Alicante', weight = 4)
network.add_edge('Valencia','Alicante', weight = 4)
network.add_edge('Murcia','Alicante', weight = 2)
network.add_edge('Murcia','Albacete', weight = 4)
network.add_edge('Murcia','Cartagena', weight = 2)
network.add_edge('Murcia','Granada', weight = 5)
network.add_edge('Murcia','Almeria', weight = 4)
network.add_edge('Almeria','Granada', weight = 3)
network.add_edge('Jaen','Granada', weight = 2)
network.add_edge('Jaen','Linares', weight = 1)
network.add_edge('Madrid','Linares', weight = 6)
network.add_edge('Antequera','Granada', weight = 2)
network.add_edge('Antequera','Malaga', weight = 2)
network.add_edge('Antequera','Almeria', weight = 4)
network.add_edge('Toledo','CiudadReal', weight = 3)
network.add_edge('Cordoba','Linares', weight = 3)
network.add_edge('Cordoba','Sevilla', weight = 3)
network.add_edge('Antequera','Sevilla', weight = 4)
network.add_edge('Cadiz','Sevilla', weight = 3)
network.add_edge('Cadiz','Algeciras', weight = 1)
network.add_edge('Algeciras','Malaga', weight = 3)
network.add_edge('Huelva','Sevilla', weight = 2)
network.add_edge('Huelva','Avamonte', weight = 1)


#nx.draw_networkx(network, node_size = 10)
nx.draw(network, node_size = 20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
